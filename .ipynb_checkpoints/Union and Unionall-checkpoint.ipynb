# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:1234@localhost/

# %%
# %%sql
# show databases
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 9 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sql_tut',),
#  ('sys',),
#  ('test',),
#  ('uber',),
#  ('world',)]

# %%
# %%sql
# use sql_tut
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS employees;
# DROP TABLE IF EXISTS contractors;
#
# CREATE TABLE employees (
#     emp_id INT NOT NULL AUTO_INCREMENT PRIMARY KEY,
#     name VARCHAR(50),
#     position VARCHAR(50),
#     hourly_rate DECIMAL(10,2)
# );
#
# CREATE TABLE contractors (
#     con_id INT NOT NULL AUTO_INCREMENT PRIMARY KEY,
#     name VARCHAR(50),
#     position VARCHAR(50),
#     hourly_rate DECIMAL(10,2)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO employees (name, position, hourly_rate) VALUES
# ('Arjun Kumar', 'Software Engineer', 850.00),
# ('Priya Sharma', 'UI/UX Designer', 750.00),
# ('Rahul Verma', 'Backend Developer', 900.00),
# ('Sneha Iyer', 'QA Engineer', 650.00),
# ('Amit Patel', 'Project Manager', 1200.00);
# INSERT INTO contractors (name, position, hourly_rate) VALUES
# ('John Smith', 'DevOps Consultant', 1500.00),
# ('Emily Brown', 'Data Analyst', 1100.00),
# ('Michael Lee', 'Cloud Architect', 1800.00),
# ('Sophia Wilson', 'Security Consultant', 1600.00),
# ('Daniel Garcia', 'Technical Writer', 700.00),
# ('Sneha Iyer', 'QA Engineer', 650.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 5 rows affected.
# 6 rows affected.
# []

# %%
# %%sql
# TRUNCATE employees
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# SELECT name, position, hourly_rate FROM employees
# UNION
# SELECT name, position, hourly_rate FROM contractors
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 10 rows affected.
# [('Arjun Kumar', 'Software Engineer', Decimal('850.00')),
#  ('Priya Sharma', 'UI/UX Designer', Decimal('750.00')),
#  ('Rahul Verma', 'Backend Developer', Decimal('900.00')),
#  ('Sneha Iyer', 'QA Engineer', Decimal('650.00')),
#  ('Amit Patel', 'Project Manager', Decimal('1200.00')),
#  ('John Smith', 'DevOps Consultant', Decimal('1500.00')),
#  ('Emily Brown', 'Data Analyst', Decimal('1100.00')),
#  ('Michael Lee', 'Cloud Architect', Decimal('1800.00')),
#  ('Sophia Wilson', 'Security Consultant', Decimal('1600.00')),
#  ('Daniel Garcia', 'Technical Writer', Decimal('700.00'))]

# %%
# %%sql
# SELECT name, position, hourly_rate FROM employees
# UNION ALL
# SELECT name, position, hourly_rate FROM contractors
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 11 rows affected.
# [('Arjun Kumar', 'Software Engineer', Decimal('850.00')),
#  ('Priya Sharma', 'UI/UX Designer', Decimal('750.00')),
#  ('Rahul Verma', 'Backend Developer', Decimal('900.00')),
#  ('Sneha Iyer', 'QA Engineer', Decimal('650.00')),
#  ('Amit Patel', 'Project Manager', Decimal('1200.00')),
#  ('John Smith', 'DevOps Consultant', Decimal('1500.00')),
#  ('Emily Brown', 'Data Analyst', Decimal('1100.00')),
#  ('Michael Lee', 'Cloud Architect', Decimal('1800.00')),
#  ('Sophia Wilson', 'Security Consultant', Decimal('1600.00')),
#  ('Daniel Garcia', 'Technical Writer', Decimal('700.00')),
#  ('Sneha Iyer', 'QA Engineer', Decimal('650.00'))]
