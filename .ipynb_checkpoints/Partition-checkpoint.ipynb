# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:1234@localhost/
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ## PARTITION
#     - Partition by range
#     - Partition by list(int) and list columns(varchar)
#     -

# %%
# %%sql
# use sql_tut
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %% [markdown]
# ## Range Partition

# %%
# %%sql
# DROP TABLE IF EXISTS orders;
#
# CREATE TABLE orders (
#     order_id   INT AUTO_INCREMENT ,
#     order_date DATE NOT NULL,
#     customer_name VARCHAR(50),
#     amount     DECIMAL(10,2),
# PRIMARY KEY(order_id, order_date)
# )
# PARTITION BY RANGE (YEAR(order_date)) (
#     PARTITION p_before_2020 VALUES LESS THAN (2020),
#     PARTITION p_2020       VALUES LESS THAN (2021),
#     PARTITION p_2021       VALUES LESS THAN (2022),
#     PARTITION p_2022       VALUES LESS THAN (2023),
#     PARTITION p_future     VALUES LESS THAN MAXVALUE
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# MAXVALUE must always be the last partition

# %%
# %%sql
# ALTER TABLE orders
# ADD PARTITION (
#     PARTITION p_2025 VALUES LESS THAN (2025)
# )

# %% [markdown]
# Your ALTER TABLE ... ADD PARTITION attempts to insert p_2025 before p_future, which MySQL does not allow
# You must reorganize the MAXVALUE partition.

# %%
# %%sql
# ALTER TABLE orders
# REORGANIZE PARTITION p_future INTO (
#     PARTITION p_2024 VALUES LESS THAN (2025),
#     PARTITION p_future VALUES LESS THAN MAXVALUE
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO orders (order_date, customer_name, amount)
# VALUES
# ('2019-05-10', 'Alice', 100.00),
# ('2020-01-15', 'Bob', 200.50),
# ('2020-12-01', 'Charlie', 300.00),
# ('2021-07-20', 'Diana', 150.75),
# ('2022-03-02', 'Edward', 500.00),
# ('2025-06-18', 'FutureMan', 9999.99);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 6 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM information_schema.PARTITIONS
# WHERE TABLE_SCHEMA = 'sql_tut'
#   AND TABLE_NAME   = 'orders';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 6 rows affected.
# [('def', 'sql_tut', 'orders', 'p_2020', None, 2, None, '0', 'RANGE', None, 'year(`order_date`)', None, '2021', 2, 8192, 16384, 0, 0, 0, datetime.datetime(2025, 12, 26, 0, 1, 41), datetime.datetime(2025, 12, 26, 0, 4, 17), None, None, '', 'default', None),
#  ('def', 'sql_tut', 'orders', 'p_2021', None, 3, None, '0', 'RANGE', None, 'year(`order_date`)', None, '2022', 1, 16384, 16384, 0, 0, 0, datetime.datetime(2025, 12, 26, 0, 1, 41), datetime.datetime(2025, 12, 26, 0, 4, 17), None, None, '', 'default', None),
#  ('def', 'sql_tut', 'orders', 'p_2022', None, 4, None, '0', 'RANGE', None, 'year(`order_date`)', None, '2023', 1, 16384, 16384, 0, 0, 0, datetime.datetime(2025, 12, 26, 0, 1, 41), datetime.datetime(2025, 12, 26, 0, 4, 17), None, None, '', 'default', None),
#  ('def', 'sql_tut', 'orders', 'p_2024', None, 5, None, '0', 'RANGE', None, 'year(`order_date`)', None, '2025', 0, 0, 16384, 0, 0, 0, datetime.datetime(2025, 12, 26, 0, 1, 41), None, None, None, '', 'default', None),
#  ('def', 'sql_tut', 'orders', 'p_before_2020', None, 1, None, '0', 'RANGE', None, 'year(`order_date`)', None, '2020', 1, 16384, 16384, 0, 0, 0, datetime.datetime(2025, 12, 26, 0, 1, 41), datetime.datetime(2025, 12, 26, 0, 4, 17), None, None, '', 'default', None),
#  ('def', 'sql_tut', 'orders', 'p_future', None, 6, None, '0', 'RANGE', None, 'year(`order_date`)', None, 'MAXVALUE', 1, 16384, 16384, 0, 0, 0, datetime.datetime(2025, 12, 26, 0, 1, 41), datetime.datetime(2025, 12, 26, 0, 4, 17), None, None, '', 'default', None)]

# %%
# %%sql
# select * from orders where order_date='2021-07-20'
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [(4, datetime.date(2021, 7, 20), 'Diana', Decimal('150.75'))]

# %%
# %%sql
# EXPLAIN FORMAT = JSON
# select * from orders where order_date='2021-07-20'
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('{\n  "query_block": {\n    "select_id": 1,\n    "cost_info": {\n      "query_cost": "0.35"\n    },\n    "table": {\n      "table_name": "orders",\n   ... (413 characters truncated) ...     "customer_name",\n        "amount"\n      ],\n      "attached_condition": "(`sql_tut`.`orders`.`order_date` = DATE\'2021-07-20\')"\n    }\n  }\n}',)]

# %% [markdown]
# ## List Partition

# %%
# %%sql
# DROP TABLE IF EXISTS employees;
#
# CREATE TABLE employees (
#     employee_id INT AUTO_INCREMENT,
#     first_name  VARCHAR(50),
#     last_name   VARCHAR(50),
#     department  VARCHAR(50),
#     primary key (employee_id,department)
# )
# PARTITION BY LIST COLUMNS (department) (
#     PARTITION p_sales       VALUES IN ('Sales'),
#     PARTITION p_hr          VALUES IN ('HR'),
#     PARTITION p_engineering VALUES IN ('Engineering', 'DevOps'),
#     PARTITION p_other       VALUES IN ('Finance', 'Marketing', 'Operations')
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO employees (first_name, last_name, department)
# VALUES
# ('Alice', 'Smith', 'Sales'),
# ('Bob', 'Johnson', 'HR'),
# ('Charlie', 'Lee', 'Engineering'),
# ('Diana', 'Lopez', 'DevOps'),
# ('Eve', 'Turner', 'Marketing');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 5 rows affected.
# []

# %%
# %%sql
# EXPLAIN FORMAT = JSON
# select * from employees where department='Sales'
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('{\n  "query_block": {\n    "select_id": 1,\n    "cost_info": {\n      "query_cost": "0.35"\n    },\n    "table": {\n      "table_name": "employees",\ ... (414 characters truncated) ... \n        "last_name",\n        "department"\n      ],\n      "attached_condition": "(`sql_tut`.`employees`.`department` = \'Sales\')"\n    }\n  }\n}',)]

# %%
# %%sql
# EXPLAIN FORMAT = JSON
# select * from employees where department IN ('Engineering', 'Sales')
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('{\n  "query_block": {\n    "select_id": 1,\n    "cost_info": {\n      "query_cost": "0.80"\n    },\n    "table": {\n      "table_name": "employees",\ ... (458 characters truncated) ... e",\n        "department"\n      ],\n      "attached_condition": "(`sql_tut`.`employees`.`department` in (\'Engineering\',\'Sales\'))"\n    }\n  }\n}',)]

# %% [markdown]
# ## Hash Partition

# %%
# %%sql
# DROP TABLE IF EXISTS sensor_data;
#
# CREATE TABLE sensor_data (
#     sensor_id     INT NOT NULL,
#     reading_time  DATETIME NOT NULL,
#     reading_value DECIMAL(10,2),
#     PRIMARY KEY (sensor_id, reading_time)
# )
# PARTITION BY HASH(sensor_id)
# PARTITIONS 2;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO sensor_data (sensor_id, reading_time, reading_value)
# VALUES
# (101, '2025-01-01 10:00:00', 23.50),
# (102, '2025-01-01 10:05:00', 24.10),
# (103, '2025-01-01 10:10:00', 22.75),
# (104, '2025-01-01 10:15:00', 25.00),
# (105, '2025-01-01 10:20:00', 20.00),
# (106, '2025-01-01 10:25:00', 21.60);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 6 rows affected.
# []

# %%
# %%sql
# explain format=json
# select * from sensor_data where sensor_id=102
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('{\n  "query_block": {\n    "select_id": 1,\n    "cost_info": {\n      "query_cost": "0.35"\n    },\n    "table": {\n      "table_name": "sensor_data" ... (517 characters truncated) ... ad_per_join": "16"\n      },\n      "used_columns": [\n        "sensor_id",\n        "reading_time",\n        "reading_value"\n      ]\n    }\n  }\n}',)]

# %% [markdown]
# ## Sub Partitions

# %%
# %%sql
# DROP TABLE IF EXISTS orders;
# CREATE TABLE orders (
#     order_id      INT AUTO_INCREMENT,
#     order_date    DATE NOT NULL,
#     customer_name VARCHAR(50),
#     amount        DECIMAL(10,2),
#     PRIMARY KEY(order_id, order_date)
# )
# PARTITION BY RANGE (YEAR(order_date))
# SUBPARTITION BY HASH (MONTH(order_date))
# SUBPARTITIONS 2
# (
#   PARTITION p_before_2020 VALUES LESS THAN (2020),
#   PARTITION p_2020        VALUES LESS THAN (2021),
#   PARTITION p_future      VALUES LESS THAN MAXVALUE
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ## Partition with Index

# %%
# %%sql
# DROP TABLE IF EXISTS orders;
#
# CREATE TABLE orders (
#     order_id      INT AUTO_INCREMENT,
#     order_date    DATE NOT NULL,
#     customer_name VARCHAR(50),
#     amount        DECIMAL(10,2),
#     PRIMARY KEY(order_id, order_date)
# )
# PARTITION BY RANGE (YEAR(order_date)) (
#     PARTITION p_before_2020 VALUES LESS THAN (2020),
#     PARTITION p_2020       VALUES LESS THAN (2021),
#     PARTITION p_2021       VALUES LESS THAN (2022),
#     PARTITION p_2022       VALUES LESS THAN (2023),
#     PARTITION p_future     VALUES LESS THAN MAXVALUE
# );
# CREATE INDEX idx_order_date ON orders (order_date);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO orders (order_date, customer_name, amount)
# VALUES
# ('2019-05-10', 'Alice', 100.00),
# ('2020-01-15', 'Bob', 200.50),
# ('2020-12-01', 'Charlie', 300.00),
# ('2021-07-20', 'Diana', 150.75),
# ('2022-03-02', 'Edward', 500.00),
# ('2025-06-18', 'FutureMan', 9999.99);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 6 rows affected.
# []

# %%
# %%sql
# EXPLAIN FORMAT = JSON
# SELECT *
# FROM orders
# WHERE order_date BETWEEN '2020-01-01' AND '2021-12-31';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('{\n  "query_block": {\n    "select_id": 1,\n    "cost_info": {\n      "query_cost": "1.61"\n    },\n    "table": {\n      "table_name": "orders",\n   ... (631 characters truncated) ... 8"\n      },\n      "used_columns": [\n        "order_id",\n        "order_date",\n        "customer_name",\n        "amount"\n      ]\n    }\n  }\n}',)]
