# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:1234@localhost/
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ## VIEW
#     -> Views do not physically store data. Instead, they derive their data from underlying tables whenever they are queried.
#     -> if i add some data to the the orginal table the view automatically updates

# %%
# %%sql
# CREATE TABLE sql_tut.employees (
#     emp_id INT PRIMARY KEY,
#     first_name VARCHAR(100),
#     last_name VARCHAR(100),
#     email VARCHAR(100),
#     hire_date DATE,
#     job_title VARCHAR(100),
#     salary DECIMAL(10,2)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO sql_tut.employees (emp_id, first_name, last_name, email, hire_date, job_title, salary) VALUES
# (1, 'Amit', 'Sharma', 'amit.sharma@example.com', '2021-03-15', 'Software Engineer', 65000.00),
# (2, 'Priya', 'Menon', 'priya.menon@example.com', '2020-07-20', 'HR Manager', 72000.00),
# (3, 'Rahul', 'Verma', 'rahul.verma@example.com', '2022-01-10', 'Data Analyst', 58000.00),
# (4, 'Sneha', 'Reddy', 'sneha.reddy@example.com', '2019-11-05', 'Project Manager', 90000.00),
# (5, 'Vikram', 'Singh', 'vikram.singh@example.com', '2021-06-18', 'DevOps Engineer', 75000.00),
# (6, 'Ananya', 'Patel', 'ananya.patel@example.com', '2022-04-12', 'UI/UX Designer', 60000.00),
# (7, 'Rohan', 'Nair', 'rohan.nair@example.com', '2020-09-28', 'QA Engineer', 55000.00),
# (8, 'Meera', 'Khan', 'meera.khan@example.com', '2023-02-14', 'Business Analyst', 63000.00),
# (9, 'Karthik', 'Iyer', 'karthik.iyer@example.com', '2021-12-01', 'Backend Developer', 70000.00),
# (10, 'Divya', 'Joshi', 'divya.joshi@example.com', '2023-05-23', 'Frontend Developer', 68000.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 10 rows affected.
# []

# %%
# %%sql
# SELECT * FROM sql_tut.employees
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 10 rows affected.
# [(1, 'Amit', 'Sharma', 'amit.sharma@example.com', datetime.date(2021, 3, 15), 'Software Engineer', Decimal('65000.00')),
#  (2, 'Priya', 'Menon', 'priya.menon@example.com', datetime.date(2020, 7, 20), 'HR Manager', Decimal('72000.00')),
#  (3, 'Rahul', 'Verma', 'rahul.verma@example.com', datetime.date(2022, 1, 10), 'Data Analyst', Decimal('58000.00')),
#  (4, 'Sneha', 'Reddy', 'sneha.reddy@example.com', datetime.date(2019, 11, 5), 'Project Manager', Decimal('90000.00')),
#  (5, 'Vikram', 'Singh', 'vikram.singh@example.com', datetime.date(2021, 6, 18), 'DevOps Engineer', Decimal('75000.00')),
#  (6, 'Ananya', 'Patel', 'ananya.patel@example.com', datetime.date(2022, 4, 12), 'UI/UX Designer', Decimal('60000.00')),
#  (7, 'Rohan', 'Nair', 'rohan.nair@example.com', datetime.date(2020, 9, 28), 'QA Engineer', Decimal('55000.00')),
# ...

# %%
# %%sql
# CREATE VIEW sql_tut.high_earners AS
# SELECT emp_id, first_name, email, salary
# FROM sql_tut.employees
# WHERE salary >= 70000
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# SELECT * FROM sql_tut.high_earners
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 4 rows affected.
# [(2, 'Priya', 'priya.menon@example.com', Decimal('72000.00')),
#  (4, 'Sneha', 'sneha.reddy@example.com', Decimal('90000.00')),
#  (5, 'Vikram', 'vikram.singh@example.com', Decimal('75000.00')),
#  (9, 'Karthik', 'karthik.iyer@example.com', Decimal('70000.00'))]

# %% [markdown]
# ## JOINS
