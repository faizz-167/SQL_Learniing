# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:1234@localhost/

# %%
# %%sql
# use test
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS employees;
# CREATE TABLE employees (
#     emp_id INT AUTO_INCREMENT PRIMARY KEY,
#     name VARCHAR(50) NOT NULL,
#     salary DECIMAL(10,2),
#     email VARCHAR(50) UNIQUE
# )
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO employees (name, salary, email) VALUES
# ('Amit Sharma',   55000.00, 'amit.sharma@company.com'),
# ('Priya Verma',   62000.50, 'priya.verma@company.com'),
# ('Rahul Kumar',   48000.75, 'rahul.kumar@company.com'),
# ('Sneha Iyer',    71000.00, 'sneha.iyer@company.com'),
# ('Arjun Patel',   60000.00, 'arjun.patel@company.com'),
# ('Neha Singh',    53000.25, 'neha.singh@company.com'),
# ('Vikram Rao',    68000.00, 'vikram.rao@company.com'),
# ('Ananya Das',    59000.90, 'ananya.das@company.com');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 8 rows affected.
# []

# %%
# %%sql
# SELECT * FROM employees
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 8 rows affected.
# [(1, 'Amit Sharma', Decimal('55000.00'), 'amit.sharma@company.com'),
#  (2, 'Priya Verma', Decimal('62000.50'), 'priya.verma@company.com'),
#  (3, 'Rahul Kumar', Decimal('48000.75'), 'rahul.kumar@company.com'),
#  (4, 'Sneha Iyer', Decimal('71000.00'), 'sneha.iyer@company.com'),
#  (5, 'Arjun Patel', Decimal('60000.00'), 'arjun.patel@company.com'),
#  (6, 'Neha Singh', Decimal('53000.25'), 'neha.singh@company.com'),
#  (7, 'Vikram Rao', Decimal('68000.00'), 'vikram.rao@company.com'),
#  (8, 'Ananya Das', Decimal('59000.90'), 'ananya.das@company.com')]

# %%
# %%sql
# SELECT *
# FROM (
#     SELECT *,
#            ROW_NUMBER() OVER (ORDER BY salary DESC) AS salRank
#     FROM employees
# ) AS ranked_employees
# WHERE salRank = 3;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [(2, 'Priya Verma', Decimal('62000.50'), 'priya.verma@company.com', 3)]

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS Students (
#     student_id INT,
#     student_name VARCHAR(20)
# );
#
# CREATE TABLE IF NOT EXISTS Subjects (
#     subject_name VARCHAR(20)
# );
#
# CREATE TABLE IF NOT EXISTS Examinations (
#     student_id INT,
#     subject_name VARCHAR(20)
# );
#
# TRUNCATE TABLE Students;
# INSERT INTO Students VALUES (1, 'Alice');
# INSERT INTO Students VALUES (2, 'Bob');
# INSERT INTO Students VALUES (13, 'John');
# INSERT INTO Students VALUES (6, 'Alex');
#
# TRUNCATE TABLE Subjects;
# INSERT INTO Subjects VALUES ('Math');
# INSERT INTO Subjects VALUES ('Physics');
# INSERT INTO Subjects VALUES ('Programming');
#
# TRUNCATE TABLE Examinations;
# INSERT INTO Examinations VALUES (1, 'Math');
# INSERT INTO Examinations VALUES (1, 'Physics');
# INSERT INTO Examinations VALUES (1, 'Programming');
# INSERT INTO Examinations VALUES (2, 'Programming');
# INSERT INTO Examinations VALUES (1, 'Physics');
# INSERT INTO Examinations VALUES (1, 'Math');
# INSERT INTO Examinations VALUES (13, 'Math');
# INSERT INTO Examinations VALUES (13, 'Programming');
# INSERT INTO Examinations VALUES (13, 'Physics');
# INSERT INTO Examinations VALUES (2, 'Math');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 0 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 0 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Subjects s
# CROSS JOIN Examinations e
# ON s.subject_name = e.subject_name
# ORDER BY s.subject_name
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 10 rows affected.
# [('Math', 1, 'Math'),
#  ('Math', 1, 'Math'),
#  ('Math', 13, 'Math'),
#  ('Math', 2, 'Math'),
#  ('Physics', 1, 'Physics'),
#  ('Physics', 1, 'Physics'),
#  ('Physics', 13, 'Physics'),
#  ('Programming', 1, 'Programming'),
#  ('Programming', 2, 'Programming'),
#  ('Programming', 13, 'Programming')]
